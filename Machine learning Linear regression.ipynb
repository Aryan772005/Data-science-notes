# %%
import pandas as pd

# %%
df = pd.read_csv("dataa.csv")

# %%
df
# Out:
#    Number  value
# 0       1     10
# 1       2     20
# 2       3     30
# 3       4     40
# 4       5     50
# 5       6     60
# 6       7     70
# 7       8     80
# 8       9     90

# %%
df.head()
# Out:
#    Number  value
# 0       1     10
# 1       2     20
# 2       3     30
# 3       4     40
# 4       5     50

# %%
df.tail()
# Out:
#    Number  value
# 4       5     50
# 5       6     60
# 6       7     70
# 7       8     80
# 8       9     90

# %%
df.head(3)
# Out:
#    Number  value
# 0       1     10
# 1       2     20
# 2       3     30

# %%
df.tail(2)
# Out:
#    Number  value
# 7       8     80
# 8       9     90

# %%
df.describe()
# Out:
#          Number      value
# count  9.000000   9.000000
# mean   5.000000  50.000000
# std    2.738613  27.386128
# min    1.000000  10.000000
# 25%    3.000000  30.000000
# 50%    5.000000  50.000000
# 75%    7.000000  70.000000
# max    9.000000  90.000000

# %%
df.columns
# Out:
# Index(['Number', 'value'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.scatter(df["Number"], df["value"])
plt.xlabel("Study Hrs")
plt.ylabel("Marks")
plt.show()

# %%
plt.figure()
plt.hist(df["Number"])
plt.hist(df["value"])

plt.xlabel("hrs")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x = df [["Number"]]

# %%
y = df[["value"]]

# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'sklearn' when getting requirements to build wheel

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\aryan\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\aryan\anaconda3\lib\site-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\aryan\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\aryan\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\aryan\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[10.]])

# %%
model.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
model.predict([[3]])
# Out:
# C:\Users\aryan\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[30.]])

# %%
plt.figure()
plt.scatter(df["Number"], df["value"])
plt.plot(x , model.predict(x))
plt.xlabel("Number")
plt.ylabel("value")
plt.show()
