# %%
import pandas as pd

# %%
df = pd.read_csv("emails.csv")

# %%
df.head()
# Out:
#                                                 text  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
df.tail()
# Out:
#                                                    text  spam
# 5723  Subject: re : research and development charges...     0
# 5724  Subject: re : receipts from visit  jim ,  than...     0
# 5725  Subject: re : enron case study update  wow ! a...     0
# 5726  Subject: re : interest  david ,  please , call...     0
# 5727  Subject: news : aurora 5 . 2 update  aurora ve...     0

# %%
df.shape
# Out:
# (5728, 2)

# %%
df.columns
# Out:
# Index(['text', 'spam'], dtype='object')

# %%
df = df [["text" , "spam"]]

# %%
df.head()
# Out:
#                                                 text  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
df.rename(columns={"text": "label", "spam": "message"}, inplace=True)

# %%
df.head()
# Out:
#                                                label  message
# 0  Subject: naturally irresistible your corporate...        1
# 1  Subject: the stock trading gunslinger  fanny i...        1
# 2  Subject: unbelievable new homes made easy  im ...        1
# 3  Subject: 4 color printing special  request add...        1
# 4  Subject: do not have money , get software cds ...        1

# %%
df.head(3)
# Out:
#                                                label  message
# 0  Subject: naturally irresistible your corporate...        1
# 1  Subject: the stock trading gunslinger  fanny i...        1
# 2  Subject: unbelievable new homes made easy  im ...        1

# %%
df.isnull().sum()
# Out:
# label      0
# message    0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#                                                   label  message
# 0     Subject: naturally irresistible your corporate...        1
# 1     Subject: the stock trading gunslinger  fanny i...        1
# 2     Subject: unbelievable new homes made easy  im ...        1
# 3     Subject: 4 color printing special  request add...        1
# 4     Subject: do not have money , get software cds ...        1
# ...                                                 ...      ...
# 5723  Subject: re : research and development charges...        0
# 5724  Subject: re : receipts from visit  jim ,  than...        0
# 5725  Subject: re : enron case study update  wow ! a...        0
# 5726  Subject: re : interest  david ,  please , call...        0
# 5727  Subject: news : aurora 5 . 2 update  aurora ve...        0
#
# [5695 rows x 2 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(33)

# %% [markdown]
# to isey ham log pata karenge ki kitna hammm log ka duplicate values ha dataset me

# %%
df=df.drop_duplicates()

# %% [markdown]
# ye duplicated values  ko remove karta ha

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import re

# %%
example = "Free enetry in 2 a weklk !!! hurrah you won fa text 7373737"

# %%
example_clean = re.sub(r"[^a-z \s]" , "" , example)

# %%
print(example_clean)
# Out:
# ree enetry in  a weklk  hurrah you won fa text

# %%
df.columns = ['message', 'label']


df['message'] = df['message'].apply(lambda x: re.sub(r'[^a-z\s]', '', str(x)))


print(df.head())
# Out:
#                                              message  label
# 0  ubject naturally irresistible your corporate i...      1
# 1  ubject the stock trading gunslinger  fanny is ...      1
# 2  ubject unbelievable new homes made easy  im wa...      1
# 3  ubject  color printing special  request additi...      1
# 4  ubject do not have money  get software cds fro...      1

# %%
df.columns = ['message', 'label']


df['message'] = df['message'].apply(lambda x: re.sub(r'[^a-z\s]', '', str(x)))


print(df.head())
# Out:
#                                              message  label
# 0  ubject naturally irresistible your corporate i...      1
# 1  ubject the stock trading gunslinger  fanny is ...      1
# 2  ubject unbelievable new homes made easy  im wa...      1
# 3  ubject  color printing special  request additi...      1
# 4  ubject do not have money  get software cds fro...      1

# %%
df['message'] = df['message'].apply(lambda x: re.sub(r'[^a-z\s]', '', str(x).lower()))

# %%
df['message'] = df['message'].apply(lambda x: re.sub(r'[^a-zA-Z\s]', '', str(x)))

# %%
import pandas as pd
import re


df = pd.read_csv('emails.csv')


df.columns = ['message', 'label']


df['message'] = df['message'].apply(lambda x: re.sub(r'[^a-z\s]', '', str(x).lower()))


print(df.head())
# Out:
#                                              message  label
# 0  subject naturally irresistible your corporate ...      1
# 1  subject the stock trading gunslinger  fanny is...      1
# 2  subject unbelievable new homes made easy  im w...      1
# 3  subject  color printing special  request addit...      1
# 4  subject do not have money  get software cds fr...      1

# %%
df.head()
# Out:
#                                              message  label
# 0  subject naturally irresistible your corporate ...      1
# 1  subject the stock trading gunslinger  fanny is...      1
# 2  subject unbelievable new homes made easy  im w...      1
# 3  subject  color printing special  request addit...      1
# 4  subject do not have money  get software cds fr...      1

# %%
# !pip install nltk

# %%
import nltk

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aryan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Error loading stopword: Package 'stopword' not found in
# [nltk_data]     index
# False

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\aryan\AppData\Roaming\nltk_data...
# True

# %%
from nltk.tokenize import word_tokenize

# %%
sample = "Hitting Aryan is not a cup of tea for you"

# %%
sample_token = word_tokenize(sample)

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\aryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# stopword are vowels and a you are not req foer machine

# %%
print(sample_token)
# Out:
# ['Hitting', 'Aryan', 'is', 'not', 'a', 'cup', 'of', 'tea', 'for', 'you']

# %%
from nltk.corpus import stopwords

# %%
import nltk
from nltk.corpus import stopwords


nltk.download('stopwords')


stop_words = set(stopwords.words('english'))


print(list(stop_words)[:10])
# Out:
# ['before', 'above', 'down', "she's", "he'll", 'shan', 'so', 'we', 'wouldn', 'some']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aryan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
stopwords = set(stopwords.words('english'))

# %%
df['message'] = df['message'].apply(lambda x: " ".join([word for word in word_tokenize(str(x)) if word not in stop_words]))

# %%
print (df["message"][2])
# Out:
# [ 'subject ' , 'unbelievable ' , 'new ' , 'homes ' , 'made ' , 'easy ' , 'im ' , 'wanting ' , 'show ' , 'homeowner ' , 'pre ' , 'approved ' , 'home ' , 'loan ' , 'fixed ' , 'rate ' , 'offer ' , 'extended ' , 'unconditionally ' , 'credit ' , 'way ' , 'factor ' , 'take ' , 'advantage ' , 'limited ' , 'time ' , 'opportunity ' , 'ask ' , 'visit ' , 'website ' , 'complete ' , 'minute ' , 'post ' , 'approval ' , 'form ' , 'look ' , 'foward ' , 'hearing ' , 'dorcas ' , 'pittman ' ]

# %%
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

stemmer = PorterStemmer()
df["message"] = df["message"].apply(
    lambda x: " ".join([stemmer.stem(word) for word in str(x).split()])
)


X = df["message"]
Y = df["label"]


vectorizer = TfidfVectorizer(max_features=3000)
X_vec = vectorizer.fit_transform(X)


X_train, X_test, Y_train, Y_test = train_test_split(
    X_vec, 
    Y, 
    test_size=0.20, 
    random_state=42
)


model = MultinomialNB()
model.fit(X_train, Y_train)





Y_pred = model.predict(X_test)


print("==MODEL OVERVIEW =======\n")

accuracy = accuracy_score(Y_test, Y_pred)
print(f"Overall Accuracy: {accuracy * 100:.2f}%\n")


print("--- Classification Report ---")
print(classification_report(Y_test, Y_pred))


print("--- Confusion Matrix ---")
print(confusion_matrix(Y_test, Y_pred))
# Out:
# ========== MODEL OVERVIEW ==========
#
# Overall Accuracy: 97.64%
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       856
#            1       0.99      0.92      0.95       290
#
#     accuracy                           0.98      1146
#    macro avg       0.98      0.96      0.97      1146
# weighted avg       0.98      0.98      0.98      1146
#
# --- Confusion Matrix ---
# [[852   4]
#  [ 23 267]]

# %%
# 1. Apna normal email
text_to_test = "Hey David, just wanted to check if we are still on for the meeting at 3pm tomorrow? Let me know!"

print(f"--- STEP 1: Original Text ---\n{text_to_test}\n")

# 2. text saf
cleaned_text = clean_custom_email(text_to_test)
print(f"--- STEP 2: Cleaned Text ---\n{cleaned_text}\n")

# 3. Translate to numbers (CRITICAL Use sey.transform()!)
numbers_to_test = vectorizer.transform([cleaned_text])


print(f"--- STEP 3: Math Check ---")
print(f"Out of the 3000 words the model knows, it recognized {numbers_to_test.nnz} words in this email.\n")

# 5 final prediction model karega
prediction = model.predict(numbers_to_test)

print(f"--- STEP 4: Final Prediction ---")
if prediction[0] == 1:
    print(" PREDICTION: SPAM!")
else:
    print(" PREDICTION: NORMAL EMAIL (HAM)")
# Out:
# --- STEP 1: Original Text ---
# Hey David, just wanted to check if we are still on for the meeting at 3pm tomorrow? Let me know!
#
# --- STEP 2: Cleaned Text ---
# hey david want check still meet pm tomorrow let know
#
# --- STEP 3: Math Check ---
# Out of the 3000 words the model knows, it recognized 10 words in this email.
#
# --- STEP 4: Final Prediction ---
#  PREDICTION: NORMAL EMAIL (HAM)

# %% [markdown]
# is model ka accuracy ha 97 per cent
