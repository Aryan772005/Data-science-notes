# %% [markdown]
# This is of missed 1st day notes

# %% [markdown]
# Tuples

# %%
mylist =["apple","mango","blueberry","apple"]

# %%
mylist[2]
# Out:
# 'blueberry'

# %%
mylist.append("cheery")

# %%
mylist
# Out:
# ['apple', 'mango', 'blueberry', 'apple', 'cheery']

# %%
mylist.count("apple")
# Out:
# 2

# %%
mylist.count("cheery")
# Out:
# 1

# %%
mylist.pop(3)
# Out:
# 'apple'

# %%
mylist.count("apple")
# Out:
# 1

# %%
mylist.sort()

# %%
mylist
# Out:
# ['mango', 'cheery', 'blueberry', 'apple']

# %%
mylist
# Out:
# ['apple', 'blueberry', 'cheery', 'mango']

# %%
mylist.reverse()

# %%
mylist
# Out:
# ['mango', 'cheery', 'blueberry', 'apple']

# %%
mylist[2]
# Out:
# 'blueberry'

# %%
for i in mylist:
    print(i)
# Out:
# mango
# cheery
# blueberry
# apple

# %% [markdown]
# we have transverse all element in my_list through forloop i si avriable it can be y

# %%
mylist.append(343434.5454)

# %%
mylist
# Out:
# ['mango', 'cheery', 'blueberry', 'apple', 343434.5454]

# %%
mylist.append("True")

# %%
mylist
# Out:
# ['mango', 'cheery', 'blueberry', 'apple', 343434.5454, 'True']

# %%
mylist =["apple","mango","blueberry","apple"]
search = input("Enter what you want to search in the List")
for i in mylist: 
    if i == search:
     print(mylist.index(i))
    else:
     print("error")
    break
# Out:
# Enter what you want to search in the List apple
# 0

# %% [markdown]
# To search the fruit from the list coede written above

# %% [markdown]
# to find frequency of apples mango task

# %% [markdown]
# tuples Started

# %%
mytuples = ("Aryan" , "Yash" , "Aditya")

# %%
tuple(mytuples)
# Out:
# ('Aryan', 'Yash', 'Aditya')

# %% [markdown]
# list ko hamlog square [] braket me likte ha aur tuples ko () , list operation jaise append kar sakta but ye nhi kar sakta

# %%
mytuples.count("tom")
# Out:
# 0

# %%
mytuples.count('Aryan')
# Out:
# 1

# %%
mydic = {
    "Name" : "Tom",
    "mob" :  2435345,
    "Mail Id":"rsjdfg@gmail.com"
}

# %%
mydic.keys()
# Out:
# dict_keys(['Name', 'mob', 'Mail Id'])

# %%
mydic.values()
# Out:
# dict_values(['Tom', 2435345, 'rsjdfg@gmail.com'])

# %% [markdown]
# we can store list and tuples in the dicnories

# %%
mydic["Name"]
# Out:
# 'Tom'

# %%
myset = {"Aryan" , 4 , 55, 56 ,3434,2.4}

# %%
myset
# Out:
# {2.4, 3434, 4, 55, 56, 'Aryan'}

# %% [markdown]
# set doesnt store the duplicate values this is the best thing of set

# %% [markdown]
# so the four data strucutre in python is = set, list , dict , tuple

# %% [markdown]
# task - how to send whasapp messages using python
# 2nd - how to send email using py
# 3rd - how to send sms using python
# 4th - how to post on inst using python
# 5th how to post on twitter using python
# using docs.python.org using library read examples to learn  how

# %%
import random
random.randint(1,10)
# Out:
# 8

# %%
print("""

   Welcome TO number Guessing game

   """)
human_choice  = int(input("Enter any number from 1 to 10"))
computer_chocie = random.randint(1,10)
if human_choice == computer_chocie:
    print("Aryan always wins")
else :
    print("its your fault learn something from Aryan")
# Out:
#    Welcome TO number Guessing game
# Enter any ni from 1 to 10 2
# its your fault learn something from Aryan
