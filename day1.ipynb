# %%
print("hi")
# Out:
# hi

# %%
name = "Aryan"

# %%
print(name)
# Out:
# Aryan

# %%
type(name)
# Out:
# str

# %%
mob = 755858585

# %%
type(mob)
# Out:
# int

# %%
age = 25.6

# %%
type(age)
# Out:
# float

# %%
ticket = True

# %%
type(ticket)
# Out:
# bool

# %%
a = 2

# %%
b = 3

# %%
a+b
# Out:
# 5

# %%
b * a
# Out:
# 6

# %%
b/a
# Out:
# 1.5

# %%
name(input("Enter your name"))
# Out:
# Enter your name Aryan
# 'Aryan'

# %%
type(name)
# Out:
# str

# %%
mobile = int(input("enetr mobile"))
# Out:
# enetr mobile 46343546354

# %% [markdown]
# type(mobile)

# %%
type(mobile)
# Out:
# int

# %%
# Comparision operator
""" line 1
line 2 line 3 used for multiline  """
# Out:
# ' line 1\nline 2 line 3 used for multiline  '

# %%
age = int(input("Enter your age"))
# Out:
# Enter your age 78

# %%
age > 18
# Out:
# True

# %%
age == 18
# Out:
# True

# %%
age > 11
# Out:
# True

# %%
age < 11
# Out:
# False

# %%
age= int(input("Enter your Age:"))
if age >= 18:
  print("person can vote ")
else:
    print("you are underage")
# Out:
# Enter your Age: 1
# you are underage

# %%
age = int(input("Enter your age :"))
ticket = True
if age>=18:
    if ticket == True:
        print("Person can Watch Movie")
else:
        print("you are underage")
# Out:
# Enter your age : 20
# Person can Watch Movie

# %%
print("""1. Addition
2. Multiplication
3. Division
4. Subtraction""")

choice = int(input("Enter what you want to choose: "))

if choice == 1:
    num1 = int(input("Enter the first number: "))
    num2 = int(input("Enter the second number: "))
    print("Addition is:", num1 + num2)
elif choice == 2:
    num1 = int(input("Enter the first number: "))
    num2 = int(input("Enter the second number: "))
    print("Multiplication is:", num1 * num2)
elif choice == 3:
    num1 = int(input("Enter the first number: "))
    num2 = int(input("Enter the second number: "))
    print("Multiplication is:", num1 / num2)
elif choice == 4:
    num1 = int(input("Enter the first number: "))
    num2 = int(input("Enter the second number: "))
    print("Substraction is:", num1 - num2)
# Out:
# 1. Addition
# 2. Multiplication
# 3. Division
# 4. Subtraction

# %%
    print("""1. Addition
2. Multiplication
3. Division
4. Subtraction""")

choice = int(input("Enter what you want to choose: "))

if choice == 1:
    num1 = int(input("Enter the first number: "))
    num2 = int(input("Enter the second number: "))
    print("Addition is:", num1 + num2)
elif choice == 2:
    num1 = int(input("Enter the first number: "))
    num2 = int(input("Enter the second number: "))
    print("Multiplication is:", num1 * num2)
elif choice == 3:
    num1 = int(input("Enter the first number: "))
    num2 = int(input("Enter the second number: "))
    print("Multiplication is:", num1 / num2)
elif choice == 4:
    num1 = int(input("Enter the first number: "))
    num2 = int(input("Enter the second number: "))
    print("Substraction is:", num1 - num2)
