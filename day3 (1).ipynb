# %% [markdown]
# Modules in Python

# %%
# !pip install SpeechRecognition
# Out:
# ...
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    - -------------------------------------- 1.6/32.9 MB 14.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 4.2/32.9 MB 12.9 MB/s eta 0:00:03
#    ------ --------------------------------- 5.2/32.9 MB 9.7 MB/s eta 0:00:03
#    ------- -------------------------------- 6.3/32.9 MB 8.5 MB/s eta 0:00:04
#    -------- ------------------------------- 7.3/32.9 MB 7.8 MB/s eta 0:00:04
#    --------- ------------------------------ 8.1/32.9 MB 7.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 8.7/32.9 MB 6.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 8.9/32.9 MB 6.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 9.4/32.9 MB 5.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 9.7/32.9 MB 4.8 MB/s eta 0:00:05
#    ------------ --------------------------- 10.2/32.9 MB 4.5 MB/s eta 0:00:06
# ...

# %%
import pywhatkit
search =input("What do you want to search")
pywhatkit.search(search)
# Out:
# What do you want to search youtube

# %%
    import speech_recognition as sr

# %%
recog = sr.Recognizer()

# %%
with sr.Microphone() as source:
    print("Speaking...")
    # Listen to the microphone input
    audio = recog.listen(source)
    
    try:
        # Send the audio to Google's free web service to convert it to text
        text = recog.recognize_google(audio)
        print("You Said:", text)
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand the audio.")
    except sr.RequestError as e:
        print(block, f"Could not request results from Google service; {e}")
# Out:
# Speaking...
# You Said: ok you listen to

# %% [markdown]
# pyjokes module

# %%
import pyjokes

joke = pyjokes.get_joke()
print(joke)
# Out:
# The Internet: where men are men, women are men, and children are FBI agents.

# %%
# !pip install qrcode[pil]

# %%
import qrcode

url = "https://www.linkedin.com/in/aryan-singh-tariani"

img = qrcode.make(url)
img.save("linkedin_qr.png")

print("LinkedIn QR Code created successfully!")
# Out:
# LinkedIn QR Code created successfully!

# %%
from IPython.display import Image, display

display(Image("linkedin_qr.png"))

# %% [markdown]
# This is my qr code of linked in (Aryan Singh)

# %% [markdown]
# NOW I WILL MAKE MENU OF ALL THIS

# %%
import pyjokes
import pywhatkit
import qrcode
import speech_recognition as sr

while True:
    print("\n===== ARYAN'S PYTHON TOOLS HUB =====")
    print("1. Generate Joke")
    print("2. Create QR Code")
    print("3. Search YouTube")
    print("4. Search Google")
    print("5. Microphone Speech to Text")
    print("6. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        print(pyjokes.get_joke())

    elif choice == "2":
        text = input("Enter text or URL: ")
        img = qrcode.make(text)
        img.save("qrcode.png")
        print("QR Code saved as qrcode.png")

    elif choice == "3":
        video = input("Enter video name: ")
        pywhatkit.playonyt(video)

    elif choice == "4":
        search = input("What do you want to search? ")
        pywhatkit.search(search)

    elif choice == "5":
        recognizer = sr.Recognizer()

        with sr.Microphone() as source:
            print("Speak something...")
            audio = recognizer.listen(source)

        try:
            text = recognizer.recognize_google(audio)
            print("You said:", text)

        except:
            print("Could not understand audio")

    elif choice == "6":
        print("Exiting...")
        break

    else:
        print("Invalid choice")
# Out:
# ===== ARYAN'S PYTHON TOOLS HUB =====
# 1. Generate Joke
# 2. Create QR Code
# 3. Search YouTube
# 4. Search Google
# 5. Microphone Speech to Text
# 6. Exit
# Enter your choice:  1
# Obfuscated Reality Mappers (ORMs) can be useful database tools.
#
# ===== ARYAN'S PYTHON TOOLS HUB =====
# 1. Generate Joke
# 2. Create QR Code
# 3. Search YouTube
# 4. Search Google
# 5. Microphone Speech to Text
# 6. Exit
# Enter your choice:  2
# Enter text or URL:  5
# QR Code saved as qrcode.png
#
# ===== ARYAN'S PYTHON TOOLS HUB =====
# 1. Generate Joke
# 2. Create QR Code
# 3. Search YouTube
# 4. Search Google
# 5. Microphone Speech to Text
# 6. Exit
# Enter your choice:  3
# Enter video name:  Rcb father of csk
# ===== ARYAN'S PYTHON TOOLS HUB =====
# 1. Generate Joke
# 2. Create QR Code
# 3. Search YouTube
# 4. Search Google
# 5. Microphone Speech to Text
# 6. Exit
